# %% [markdown]
# *   Instalando o OPENCV

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.25.2)

# %% [markdown]
# *  Importando bibliotecas

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# *   Matriz para guardar imagem

# %%
img = cv2.imread('/content/drive/MyDrive/PIM/Imagens/ilha.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x584>

# %% [markdown]
# *   Imagem em tons de cinza

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=1024x584>

# %% [markdown]
# *  AZUL

# %%
import copy

img_blue = copy.copy(img)

img_blue[:,:,1] = 0
img_blue[:,:,2] = 0
cv2_imshow(img_blue)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x584>

# %% [markdown]
# *   VERDE

# %%
imag_green = copy.copy(img)

imag_green[:,:,0] = 0
imag_green[:,:,2] = 0
cv2_imshow(imag_green)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x584>

# %% [markdown]
# *   VERMELHO

# %%
imag_red = copy.copy(img)

imag_red[:,:,0] = 0
imag_red[:,:,1] = 0
cv2_imshow(imag_red)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x584>
